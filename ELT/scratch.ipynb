# %%
import nba_api
import requests
import csv
from pathlib import Path
import pandas as pd

data_dir = Path("kaggle data")
games_df = pd.read_csv(data_dir / "Games.csv")
player_stats_df = pd.read_csv(data_dir / "PlayerStatisticsExtended.csv")
# Out:
# /var/folders/w4/vy2sc7b16d381_mftzw3ttg00000gn/T/ipykernel_11223/1079596445.py:8: DtypeWarning: Columns (0: gameSubtype, 1: gameSubLabel, 2: seriesGameNumber, 3: arenaName, 4: arenaCity, 5: arenaState, 6: officials) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_df = pd.read_csv(data_dir / "Games.csv")
# /var/folders/w4/vy2sc7b16d381_mftzw3ttg00000gn/T/ipykernel_11223/1079596445.py:9: DtypeWarning: Columns (0: gameDateTimeEst, 1: gameLabel, 2: gameSubLabel, 3: seriesGameNumber, 4: playerteamName, 5: opponentteamCity, 6: opponentteamName, 7: comment, 8: startingPosition, 9: numMinutes) have mixed types. Specify dtype option on import or set low_memory=False.
#   player_stats_df = pd.read_csv(data_dir / "PlayerStatisticsExtended.csv")
# (     gameId      gameDateTimeEst   hometeamCity hometeamName  hometeamId  \
#  0  42500232  2026-05-06 21:30:00    San Antonio        Spurs  1610612759
# ...

# %%
games_df = games_df.loc[games_df["gameType"] == "Playoffs"]
player_stats_df = player_stats_df.loc[player_stats_df["gameType"] == "Playoffs"]

print(games_df)
# Out:
#          gameId      gameDateTimeEst   hometeamCity hometeamName  hometeamId  \
# 0      42500232  2026-05-06 21:30:00    San Antonio        Spurs  1610612759
# 1      42500212  2026-05-06 19:00:00       New York       Knicks  1610612752
# 2      42500221  2026-05-05 20:30:00  Oklahoma City      Thunder  1610612760
# 3      42500201  2026-05-05 19:00:00        Detroit      Pistons  1610612765
# 4      42500231  2026-05-04 21:30:00    San Antonio        Spurs  1610612759
# ...         ...                  ...            ...          ...         ...
# 72998  44900231  1950-03-22 19:00:00       Syracuse    Nationals  1610612755
# 73121  44800312  1949-03-29 19:00:00    Minneapolis       Lakers  1610612747
# 73122  44800311  1949-03-27 19:00:00      Rochester       Royals  1610612758
# 73228  44600212  1947-04-14 19:00:00       New York       Knicks  1610612752
# 73229  44600211  1947-04-12 19:00:00   Philadelphia     Warriors  1610612744
#
# ...
